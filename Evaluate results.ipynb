# %%
from pymongo import MongoClient
from odt.database import load_ontology, load_dataset, load_similarity, load_autotagged
from odt.opendatasemanticframework import OpenDataSemanticFramework
from os import path, environ

uri = 'mongodb://{0}:{1}@ds119969.mlab.com:19969/ontodb'.format('nims','******')
#ontology_graph = load_ontology(uri, config['5afc0fb801d5415a9d324003'])

# %%
def get_search_entry(uri):
    client = MongoClient(uri)
    db = client.ontodb
    for log in db.log.find():
        yield log

# %%
import json

unique_ip = []
for json_data in get_search_entry(uri):
    ip = json_data["ip"] 
    if not ip in unique_ip:
        unique_ip.append(ip)
    if not ip == "127.0.0.1":        
        print (json_data["ip"])    
        print (json_data["time"])
        print (json_data["query"])
        print (json_data["type"])
        # print (json_data["res"])
        print ('\n')
        
print (unique_ip)
# Out:
# 10.33.188.84
# 2018-05-23 19:58:55
# charging station
# tagged
#
#
# 10.65.99.67
# 2018-05-23 20:25:06
# battery
# tagged
#
#
# 10.30.228.16
# 2018-05-23 20:48:05
# battery
# tagged
#
#
# 10.228.182.163
# 2018-05-23 21:23:43
# concepts
# tagged
#
#
# 10.65.99.67
# 2018-05-23 20:24:45
# charging station
# auto
#
#
# 10.65.99.67
# 2018-05-23 20:25:00
# battery
# auto
#
#
# 10.65.99.67
# 2018-05-23 20:25:11
# battery
# auto
#
#
# 10.228.182.163
# 2018-05-23 21:23:54
# battery
# tagged
#
#
# 10.228.182.163
# 2018-05-23 21:23:58
# battery
# auto
#
#
# 10.11.215.44
# 2018-05-23 21:23:59
# battery
# auto
#
#
# 10.101.153.165
# 2018-05-24 07:42:55
# charging station
# tagged
#
#
# 10.101.153.165
# 2018-05-24 07:43:00
# charging station
# tagged
#
#
# 10.151.201.12
# 2018-05-24 07:44:26
# charging station
# auto
#
#
# 10.43.197.68
# 2018-05-24 14:17:43
# charging station in stavanger
# tagged
#
#
# 10.43.197.68
# 2018-05-24 14:18:14
# charging station in stavanger
# auto
#
#
# 10.47.190.238
# ...
